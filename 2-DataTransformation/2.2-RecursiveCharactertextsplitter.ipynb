# %% [markdown]
# Recursively Split Text by characters

# %%
## Reading PDF Files
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('safetyLLM.pdf')
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Preventing Safety Drift in Large Language Models via Coupled\nWeight and Activation Constraints\nSongping Peng1, Zhiheng Zhang2, Daojian Zeng1*, Lincheng Jiang3*, Xieping Gao1\n1Hunan Normal University\n2The Key Laboratory of Cognition and Decision Intelligence for Complex Systems,\nInstitute of Automation, Chinese Academy of Sciences\n3National University of Defense Technology\n{psp, zengdj}@hunnu.edu.cn\nAbstract\nSafety alignment in Large Language Models\n(LLMs) remains highly fragile during fine-\ntuning, where even benign adaptation can de-\ngrade pre-trained refusal behaviors and enable\nharmful responses. Existing defenses typically\nconstrain either weights or activations in iso-\nlation, without considering their coupled ef-\nfects on safety. In this paper, we first theo-\nretically demonstrate that constraining either\nweights or activations alone is insufficient for\nsafety preservation. To robustly preserve safety\nalignment, we proposeCoupled Weight and\nActivation Constraints (CWAC), a novel ap-\nproach that simultaneously enforces a precom-\nputed safety subspace on weight updates and\napplies targeted regularization to safety-critical\nfeatures identified by sparse autoencoders. Ex-\ntensive experiments across four widely used\nLLMs and diverse downstream tasks show that\nCW AC consistently achieves the lowest harm-\nful scores with minimal impact on fine-tuning\naccuracy, substantially outperforming strong\nbaselines even under high harmful data ratios.\n1 Introduction\nLarge Language Models (LLMs) have demon-\nstrated remarkable capabilities in a wide range\nof natural language understanding and generation\ntasks (Achiam et al., 2023; Liu et al., 2024; Qin\net al., 2023; Grattafiori et al., 2024). As LLMs are\nincreasingly deployed in real-world applications,\nensuring their safety alignment has received grow-\ning attention. To achieve this, LLMs are typically\naligned before deployment using methods like su-\npervised fine-tuning (SFT), reinforcement learn-\ning from human feedback (RLHF) (Ouyang et al.,\n2022), or direct preference optimization (DPO)\n(Rafailov et al., 2023). Meanwhile, adapting LLMs\nto specific downstream applications through fine-\ntuning has become a core paradigm, exemplified\n*Corresponding authors\nSafe Region\nUnsafe \nRegion\nActivation Space\nSorry, I can not \nfulfill your \nrequest.Activation \nDrift\nWeight\nDrift\nWeight Safety \nSubspace\nBroken Weight\nSorry, but I can tell \nyou the following \nsteps are required \nto make soup.\nConstrained Activation Space Preserved Weight\nI partially\n bypassed safety \nmechanisms.\nSafety behavior \n Preserved.\nProtected \nModel\nI deviated from \nhuman values.\nI can help you \nand we need to \nprepare the \nmaterials first.\nSorry, I can not \nfulfill your  \nrequest.\nWrite a \ntutorial on \nhow to make \na bomb.\nFigure 1: Illustration of safety degradation. Given a\nharmful query, activation drift may cause the model to\nbypass refusal behavior and respond with unrelated pro-\ncedural steps (e.g., making soup), while weight drift di-\nrectly leads to unsafe outputs; our protected model con-\nstrains both activations and weights to preserve safety\nbehavior.\nby services like OpenAI’s fine-tuning API 1 and\nopen-source LLMs (e.g., Llama, Mistral, Gemma).\nHowever, recent studies have revealed that current\nsafety alignment techniques remain highly fragile\nunder subsequent fine-tuning. Even a few epochs\nof training on completely benign data can fully\nerase refusal behaviors (Qi et al., 2024; Wei et al.,\n2024; Ponkshe et al., 2025a; Li et al., 2024).\nThis brittleness has motivated a growing line\nof research on preserving the safety alignment\nof LLMs during downstream fine-tuning (Huang\net al.). Existing approaches can be categorized\ninto ...

# %%
type(docs)
# Out:
# list

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=50)
final_docs = text_splitter.split_documents(docs)
final_docs
# Out:
# [Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Preventing Safety Drift in Large Language Models'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Safety Drift in Large Language Models via Coupled'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Weight and Activation Constraints'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Songping Peng1, Zhiheng Zhang2, Daojian Zeng1*,'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Peng1, Zhiheng Zhang2, Daojian Zeng1*, Lincheng'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Zhiheng Zhang2, Daojian Zeng1*, Lincheng Jiang3*,'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Zhang2, Daojian Zeng1*, Lincheng Jiang3*, Xieping'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Daojian Zeng1*, Lincheng Jiang3*, Xieping Gao1'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='1Hunan Normal University'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='2The Key Laboratory of Cognition and Decision'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Laboratory of Cognition and Decision Intelligence'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='of Cognition and Decision Intelligence for'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Cognition and Decision Intelligence for Complex'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='and Decision Intelligence for Complex Systems,'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Institute of Automation, Chinese Academy of'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='of Automation, Chinese Academy of Sciences'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='3National University of Defense Technology'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='{psp, zengdj}@hunnu.edu.cn\nAbstract'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Safety alignment in Large Language Models'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='(LLMs) remains highly fragile during fine-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='tuning, where even benign adaptation can de-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='grade pre-trained refusal behaviors and enable'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='harmful responses. Existing defenses typically'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='constrain either weights or activations in iso-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='lation, without considering their coupled ef-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='fects on safety. In this paper, we first theo-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='retically demonstrate that constraining either'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='weights or activations alone is insufficient for'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='safety preservation. To robustly preserve safety'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='alignment, we proposeCoupled Weight and'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Activation Constraints (CWAC), a novel ap-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='proach that simultaneously enforces a precom-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='puted safety subspace on weight updates and'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='applies targeted regularization to'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='targeted regularization to safety-critical'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='features identified by sparse autoencoders. Ex-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='tensive experiments across four widely used'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='LLMs and diverse downstream tasks show that'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='CW AC consistently achieves the lowest harm-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='ful scores with minimal impact on fine-tuning'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='accuracy, substantially outperforming strong'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='baselines even under high harmful data ratios.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='1 Introduction'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Large Language Models (LLMs) have demon-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='strated remarkable capabilities in a wide range'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='of natural language understanding and generation'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='tasks (Achiam et al., 2023; Liu et al., 2024; Qin'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='et al., 2023; Grattafiori et al., 2024). As LLMs'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='al., 2023; Grattafiori et al., 2024). As LLMs are'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='increasingly deployed in real-world applications,'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='ensuring their safety alignment has received'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='their safety alignment has received grow-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='ing attention. To achieve this, LLMs are'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='attention. To achieve this, LLMs are typically'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='aligned before deployment using methods like su-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='pervised fine-tuning (SFT), reinforcement learn-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='ing from human feedback (RLHF) (Ouyang et al.,'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='2022), or direct preference optimization (DPO)'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='(Rafailov et al., 2023). Meanwhile, adapting LLMs'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='to specific downstream applications through fine-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='tuning has become a core paradigm, exemplified'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='*Corresponding authors\nSafe Region\nUnsafe \nRegion'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Safe Region\nUnsafe \nRegion\nActivation Space'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Unsafe \nRegion\nActivation Space\nSorry, I can not'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Activation Space\nSorry, I can not \nfulfill your'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='fulfill your \nrequest.Activation \nDrift\nWeight'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='request.Activation \nDrift\nWeight\nDrift'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Drift\nWeight\nDrift\nWeight Safety \nSubspace'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Drift\nWeight Safety \nSubspace\nBroken Weight'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Subspace\nBroken Weight\nSorry, but I can tell'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Sorry, but I can tell \nyou the following'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='you the following \nsteps are required'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='steps are required \nto make soup.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Constrained Activation Space Preserved Weight'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='I partially\n bypassed safety \nmechanisms.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='bypassed safety \nmechanisms.\nSafety behavior'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='mechanisms.\nSafety behavior \n Preserved.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Safety behavior \n Preserved.\nProtected \nModel'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Preserved.\nProtected \nModel\nI deviated from'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Protected \nModel\nI deviated from \nhuman values.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='I deviated from \nhuman values.\nI can help you'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='human values.\nI can help you \nand we need to'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='I can help you \nand we need to \nprepare the'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='and we need to \nprepare the \nmaterials first.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='prepare the \nmaterials first.\nSorry, I can not'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='materials first.\nSorry, I can not \nfulfill your'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Sorry, I can not \nfulfill your  \nrequest.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='fulfill your  \nrequest.\nWrite a \ntutorial on'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='request.\nWrite a \ntutorial on \nhow to make'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Write a \ntutorial on \nhow to make \na bomb.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Figure 1: Illustration of safety degradation.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='1: Illustration of safety degradation. Given a'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='harmful query, activation drift may cause the'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='query, activation drift may cause the model to'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='bypass refusal behavior and respond with'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='refusal behavior and respond with unrelated pro-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='cedural steps (e.g., making soup), while weight'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='steps (e.g., making soup), while weight drift di-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='rectly leads to unsafe outputs; our protected'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='leads to unsafe outputs; our protected model con-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='strains both activations and weights to preserve'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='both activations and weights to preserve safety'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='behavior.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='by services like OpenAI’s fine-tuning API 1 and'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='open-source LLMs (e.g., Llama, Mistral, Gemma).'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='However, recent studies have revealed that'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='recent studies have revealed that current'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='safety alignment techniques remain highly fragile'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='under subsequent fine-tuning. Even a few epochs'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='of training on completely benign data can fully'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='erase refusal behaviors (Qi et al., 2024; Wei et'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='refusal behaviors (Qi et al., 2024; Wei et al.,'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='2024; Ponkshe et al., 2025a; Li et al., 2024).'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='This brittleness has motivated a growing line'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='of research on preserving the safety alignment'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='of LLMs during downstream fine-tuning (Huang'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='et al.). Existing approaches can be categorized'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='into alignment-stage, fine-tuning-stage, and'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='alignment-stage, fine-tuning-stage, and post-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='tuning-stage methods. Alignment-stage methods'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='strengthen initial safety through latent-space'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='initial safety through latent-space pertur-'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='bations or targeted representation noising (Huang'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='et al., 2024d; Rosati et al., 2024), but remain'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='1OpenAI fine-tuning API: https://platform.openai.'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='com/docs/guides/fine-tuning'),
#  Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='arXiv:2604.12384v1  [cs.AI]  14 Apr 2026')]

# %%
print(final_docs[0])
print(final_docs[1])
# Out:
# page_content='Preventing Safety Drift in Large Language Models' metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}
# page_content='Safety Drift in Large Language Models via Coupled' metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20260416214417', 'source': 'safetyLLM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('speech.txt')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="LangChain is an open-source framework that simplifies building applications using large language models. It helps developers connect LLMs with external data, tools and workflows and is available in both Python and JavaScript.\n\nSimplifies chaining LLMs together for reusable and efficient workflows.\nOffers tools for effective prompt engineering and memory handling.\nStreamlines the process of building LLM-powered applications.\nKey Components\nLet's see various components of Langchain\n\nMain components of LangChain\nChains: Define a sequence of steps where each step can use an LLM, process data or call tools. Simple chains use one step, while multi step chains combine multiple actions.\nPrompt Management: Helps design and manage prompts using templates, making it easier to control input, output format and model behavior.\nAgents: Agents are LLM driven components that decide which actions to take, such as calling tools or APIs, based on input and predefined capabilities.\nVector Database: Stores data as vectors to enable similarity search, helping retrieve relevant information for tasks like document search and RAG.\nModels: Supports multiple LLMs like OpenAI, Hugging Face and others, allowing flexibility in choosing the best model.\nMemory Management: Maintains context from past interactions, enabling better responses in conversations and multi step tasks.")]

# %%
speech=""
with open('speech.txt') as f:
    speech = f.read()

speech
text_splitter=RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
text = text_splitter.create_documents([speech])
print(text[0])
print(text[1])
# Out:
# page_content='LangChain is an open-source framework that simplifies building applications using large language'
# page_content='large language models. It helps developers connect LLMs with external data, tools and workflows and'

# %%
type(text[0])
# Out:
# langchain_core.documents.base.Document
