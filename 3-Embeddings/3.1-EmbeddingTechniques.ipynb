# %% [markdown]
# Embedding Techniques
# Converting text into vectors

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x00000265A0A91FF0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x00000265A0A931F0>, model='text-embedding-3-large', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
text = "This is an OpenAI embedding"
query_result = embeddings.embed_query(text)
query_result
# Out:
# [-0.000301361083984375,
#  0.033294677734375,
#  -0.00714874267578125,
#  -0.024169921875,
#  0.014923095703125,
#  -0.00846099853515625,
#  0.01045989990234375,
#  0.04742431640625,
#  -0.006439208984375,
#  -0.01044464111328125,
#  -0.01282501220703125,
#  0.0078582763671875,
#  0.003528594970703125,
#  0.01143646240234375,
#  -0.020538330078125,
#  0.037139892578125,
#  0.00868988037109375,
#  0.05169677734375,
#  -0.032318115234375,
#  -0.026947021484375,
#  -0.0007348060607910156,
#  -0.020965576171875,
#  -0.0205078125,
#  -0.035919189453125,
#  0.035797119140625,
#  -0.032318115234375,
#  0.01461029052734375,
#  0.02984619140625,
#  -0.033782958984375,
#  0.047454833984375,
#  0.01305389404296875,
#  -0.0165252685546875,
#  0.01031494140625,
#  -0.01250457763671875,
#  -0.0003440380096435547,
#  0.0177764892578125,
#  0.035552978515625,
#  0.048431396484375,
#  -0.0296173095703125,
#  0.00637054443359375,
#  0.0287628173828125,
#  -0.00208282470703125,
#  -0.0118408203125,
#  0.0160980224609375,
#  -0.016998291015625,
#  -0.0081329345703125,
#  0.0166778564453125,
#  -0.0119476318359375,
#  -0.0186767578125,
#  -0.004192352294921875,
#  0.01045989990234375,
#  -0.0234375,
#  0.0163421630859375,
#  -0.035247802734375,
#  -0.015899658203125,
#  0.020751953125,
#  0.033905029296875,
#  0.0117034912109375,
#  0.0694580078125,
#  0.0283050537109375,
#  -0.0011186599731445312,
#  0.0247344970703125,
#  -0.01776123046875,
#  -0.01351165771484375,
#  -0.0058135986328125,
#  -0.0127716064453125,
#  0.02386474609375,
#  -0.0035648345947265625,
#  -0.0019702911376953125,
#  0.026123046875,
#  -0.022552490234375,
#  -0.0186614990234375,
#  -0.01194000244140625,
#  0.0041656494140625,
#  0.037200927734375,
#  0.041412353515625,
#  0.039642333984375,
#  0.006923675537109375,
#  -0.01334381103515625,
#  0.00281524658203125,
#  0.04620361328125,
#  -0.0063629150390625,
#  0.0222625732421875,
#  0.01270294189453125,
#  0.060302734375,
#  0.038787841796875,
#  0.01410675048828125,
#  -0.0635986328125,
#  -0.01605224609375,
#  0.031097412109375,
#  -0.05181884765625,
#  0.04473876953125,
#  -0.041259765625,
#  -0.011810302734375,
#  0.0002028942108154297,
#  -0.00849151611328125,
#  -0.00949859619140625,
#  0.006683349609375,
#  0.0029296875,
#  0.0291595458984375,
#  -0.01160430908203125,
#  -0.0231170654296875,
#  -0.0011119842529296875,
#  -0.0030536651611328125,
#  -0.0229949951171875,
#  0.0089569091796875,
#  0.01708984375,
#  0.020904541015625,
#  0.00395965576171875,
#  0.04425048828125,
#  0.0195159912109375,
#  -0.022552490234375,
#  -0.04254150390625,
#  0.0177764892578125,
#  -0.01023101806640625,
#  -0.00656890869140625,
#  -0.0236663818359375,
#  0.0278778076171875,
#  -0.00511932373046875,
#  0.006195068359375,
#  0.025421142578125,
#  -0.0221710205078125,
#  0.0433349609375,
#  -0.014251708984375,
#  -0.01366424560546875,
#  0.0143280029296875,
#  0.00588226318359375,
#  0.01184844970703125,
#  -0.01247406005859375,
#  0.013641357421875,
#  0.0011920928955078125,
#  -0.0002620220184326172,
#  -0.039398193359375,
#  0.01861572265625,
#  0.00481414794921875,
#  0.023193359375,
#  0.0007185935974121094,
#  -0.031646728515625,
#  -0.00457763671875,
#  -0.0155487060546875,
#  0.00640106201171875,
#  0.0267486572265625,
#  0.0167388916015625,
#  0.01702880859375,
#  -0.00972747802734375,
#  0.00433349609375,
#  0.01108551025390625,
#  -0.02667236328125,
#  0.0098419189453125,
#  0.00278472900390625,
#  0.006740570068359375,
#  0.015869140625,
#  -0.00389862060546875,
#  0.038970947265625,
#  -0.0251007080078125,
#  0.0086822509765625,
#  0.0067596435546875,
#  0.004581451416015625,
#  0.0169219970703125,
#  0.006679534912109375,
#  0.00684356689453125,
#  0.025787353515625,
#  0.01715087890625,
#  -0.0013074874877929688,
#  0.023284912109375,
#  -0.0174560546875,
#  0.0154571533203125,
#  0.00502777099609375,
#  -0.0103759765625,
#  0.029388427734375,
#  -0.031463623046875,
#  -0.01837158203125,
#  -0.054351806640625,
#  -0.005901336669921875,
#  0.017486572265625,
#  -0.00616455078125,
#  -0.030487060546875,
#  -0.041229248046875,
#  -0.046966552734375,
#  0.00939178466796875,
#  -0.0106658935546875,
#  -0.006725311279296875,
#  0.0089569091796875,
#  0.00948333740234375,
#  0.0037097930908203125,
#  -0.0153045654296875,
#  -0.03790283203125,
#  -0.01374053955078125,
#  -0.00780487060546875,
#  0.01457977294921875,
#  -0.007049560546875,
#  -0.004467010498046875,
#  0.006683349609375,
#  -0.020477294921875,
#  0.024383544921875,
#  -0.01137542724609375,
#  -0.033538818359375,
#  0.02081298828125,
#  0.00039768218994140625,
#  -0.00542449951171875,
#  0.0107421875,
#  -0.0035724639892578125,
#  0.00920867919921875,
#  0.006298065185546875,
#  -0.021209716796875,
#  -0.049713134765625,
#  0.0213623046875,
#  -0.006786346435546875,
#  0.0258941650390625,
#  -0.0019092559814453125,
#  -0.003452301025390625,
#  0.016998291015625,
#  -0.00746917724609375,
#  -0.013824462890625,
#  0.00763702392578125,
#  -0.00612640380859375,
#  0.023223876953125,
#  0.0015916824340820312,
#  0.042388916015625,
#  -0.01727294921875,
#  0.01221466064453125,
#  -0.005290985107421875,
#  0.03143310546875,
#  0.004215240478515625,
#  -0.0239105224609375,
#  -0.01031494140625,
#  0.036590576171875,
#  0.00807952880859375,
#  -0.038543701171875,
#  0.01287078857421875,
#  -0.009490966796875,
#  -0.006061553955078125,
#  -0.005313873291015625,
#  0.0159912109375,
#  0.0097503662109375,
#  0.0091400146484375,
#  -0.0440673828125,
#  -0.00927734375,
#  0.015777587890625,
#  0.006534576416015625,
#  -0.00724029541015625,
#  0.018310546875,
#  0.0369873046875,
#  -0.003925323486328125,
#  -0.00722503662109375,
#  -0.00658416748046875,
#  0.007007598876953125,
#  -0.0223846435546875,
#  -0.015106201171875,
#  -0.0321044921875,
#  -0.01255035400390625,
#  -0.0252227783203125,
#  0.0015344619750976562,
#  0.00970458984375,
#  -0.0015964508056640625,
#  0.0253753662109375,
#  0.01203155517578125,
#  0.01959228515625,
#  -0.00685882568359375,
#  -0.01904296875,
#  -0.040771484375,
#  -0.0128326416015625,
#  -0.00027179718017578125,
#  0.031982421875,
#  0.01180267333984375,
#  0.01371002197265625,
#  0.017242431640625,
#  0.00811767578125,
#  0.0014362335205078125,
#  -0.0016107559204101562,
#  -0.0037746429443359375,
#  -0.0185394287109375,
#  -0.00688934326171875,
#  -0.008209228515625,
#  0.029205322265625,
#  -0.01195526123046875,
#  0.0279388427734375,
#  0.040618896484375,
#  0.01169586181640625,
#  0.0199432373046875,
#  -0.00910186767578125,
#  -0.00441741943359375,
#  0.00731658935546875,
#  -0.0679931640625,
#  0.0035839080810546875,
#  -0.036712646484375,
#  0.00626373291015625,
#  -0.019256591796875,
#  0.00959014892578125,
#  0.01030731201171875,
#  0.0191650390625,
#  0.0026302337646484375,
#  -0.00020313262939453125,
#  -0.02642822265625,
#  0.0157318115234375,
#  0.0060272216796875,
#  0.0152740478515625,
#  -0.00774383544921875,
#  0.004726409912109375,
#  0.00342559814453125,
#  0.0533447265625,
#  -0.0006356239318847656,
#  -0.003765106201171875,
#  0.04425048828125,
#  0.03839111328125,
#  -0.0112457275390625,
#  -0.00934600830078125,
#  -0.0241546630859375,
#  -0.03204345703125,
#  -0.005245208740234375,
#  0.0018854141235351562,
#  0.0123138427734375,
#  -0.03118896484375,
#  0.0211029052734375,
#  0.0202484130859375,
#  0.0291748046875,
#  0.0066070556640625,
#  -0.028350830078125,
#  -0.01215362548828125,
#  0.0096893310546875,
#  0.01244354248046875,
#  -0.0171966552734375,
#  0.003734588623046875,
#  0.025482177734375,
#  -0.0013933181762695312,
#  0.002727508544921875,
#  0.003055572509765625,
#  -0.027679443359375,
#  0.0182952880859375,
#  -0.019500732421875,
#  0.00473785400390625,
#  -0.00371551513671875,
#  -0.02294921875,
#  0.0180206298828125,
#  -0.021942138671875,
#  0.0294342041015625,
#  -0.021820068359375,
#  -0.007640838623046875,
#  -0.0008745193481445312,
#  -0.002796173095703125,
#  -0.02197265625,
#  -0.0021152496337890625,
#  -0.002529144287109375,
#  -0.0121612548828125,
#  -0.01715087890625,
#  0.0053558349609375,
#  0.01541900634765625,
#  -0.018585205078125,
#  0.008514404296875,
#  -0.007053375244140625,
#  -0.001781463623046875,
#  -0.0242156982421875,
#  -0.00785064697265625,
#  0.005306243896484375,
#  0.01319122314453125,
#  0.00803375244140625,
#  0.044189453125,
#  0.000980377197265625,
#  -0.0031490325927734375,
#  0.0012006759643554688,
#  -0.0132293701171875,
#  0.004871368408203125,
#  0.0284576416015625,
#  0.00199127197265625,
#  0.00994873046875,
#  0.0455322265625,
#  -0.01873779296875,
#  0.011444091796875,
#  0.0352783203125,
#  -0.01324462890625,
#  -0.039520263671875,
#  -0.004154205322265625,
#  -0.0009379386901855469,
#  -0.0169219970703125,
#  -0.0014810562133789062,
#  -0.03094482421875,
#  -0.00701904296875,
#  0.0242919921875,
#  -0.01190948486328125,
#  -0.0164947509765625,
#  -0.0015172958374023438,
#  -0.0074462890625,
#  ...]

# %%
query_result[0]
# Out:
# -0.000301361083984375

# %%
len(query_result)
# Out:
# 3072

# %%
embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-large", dimensions=1024)

# %%
embeddings_1024
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x00000265B9A2CFD0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x00000265B9A2CAF0>, model='text-embeddings-3-large , dimensions= 1024', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
text = "This is an OpenAI embedding"
query_result_1024= embeddings_1024.embed_query(text)
query_result_1024
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[31], line 2
#       1 text = "This is an OpenAI embedding"
# ----> 2 query_result_1024= embeddings_1024.embed_query(text)
#       3 query_result_1024
#
# File c:\Users\Sejal Pc\Desktop\Langchain\venv\lib\site-packages\langchain_openai\embeddings\base.py:801, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     791 """Call out to OpenAI's embedding endpoint for embedding query text.
#     792
#     793 Args:
#    (...)
#     798     Embedding for the text.
#     799 """
#     800 self._ensure_sync_client_available()
# --> 801 return self.embed_documents([text], **kwargs)[0]
#
# File c:\Users\Sejal Pc\Desktop\Langchain\venv\lib\site-packages\langchain_openai\embeddings\base.py:751, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     748 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     749 # This could be optimized to avoid double work when all texts are short enough.
#     750 engine = cast(str, self.deployment)
# --> 751 return self._get_len_safe_embeddings(
#     752     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     753 )
#
# File c:\Users\Sejal Pc\Desktop\Langchain\venv\lib\site-packages\langchain_openai\embeddings\base.py:618, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     616 # Make API call with this batch
#     617 batch_tokens = tokens[i:batch_end]
# --> 618 response = self.client.create(input=batch_tokens, **client_kwargs)
#     619 if not isinstance(response, dict):
#     620     response = response.model_dump()
#
# File c:\Users\Sejal Pc\Desktop\Langchain\venv\lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145     ),
#     146     cast_to=CreateEmbeddingResponse,
#     147 )
#
# File c:\Users\Sejal Pc\Desktop\Langchain\venv\lib\site-packages\openai\_base_client.py:1314, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1305     warnings.warn(
#    1306         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1307         "Please pass raw bytes via the `content` parameter instead.",
#    1308         DeprecationWarning,
#    1309         stacklevel=2,
#    1310     )
#    1311 opts = FinalRequestOptions.construct(
#    1312     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1313 )
# -> 1314 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Sejal Pc\Desktop\Langchain\venv\lib\site-packages\openai\_base_client.py:1087, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1084             err.response.read()
#    1086         log.debug("Re-raising status error")
# -> 1087         raise self._make_status_error_from_response(err.response) from None
#    1089     break
#    1091 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'invalid model ID', 'type': 'invalid_request_error', 'param': None, 'code': None}}
