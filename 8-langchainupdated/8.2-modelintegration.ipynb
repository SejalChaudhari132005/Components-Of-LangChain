# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]= os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]= os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]= os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-5.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.5.5', 'langchain': '1.3.15', 'langchain-openai': '1.5.1'}}, profile={'name': 'GPT-5.1', 'release_date': '2025-11-13', 'last_updated': '2025-11-13', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True, 'reasoning_effort_levels': ['none', 'low', 'medium', 'high', 'xhigh']}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000024F1CE92090>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000024F1D896890>, root_client=<openai.OpenAI object at 0x0000024F1CE91C90>, root_async_client=<openai.AsyncOpenAI object at 0x0000024F1D896410>, model_name='gpt-5.1', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
### invoke the model
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content='I’m doing well, thanks for asking. How are you doing today, and what can I help you with?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 11, 'total_tokens': 43, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.1-2025-11-13', 'system_fingerprint': None, 'id': 'chatcmpl-EOobXrNDciaURem7S2u5CwaX0Mf6r', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0ab76-fa42-7521-bf26-c932533a7807-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 32, 'total_tokens': 43, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
### Google GEMINI model Integration
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"]= os.getenv("GOOGLE_API_KEY")

model = init_chat_model(
    "gemini-2.5-flash",
    model_provider="google_genai",
)
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots talk due to a fascinating combination of unique anatomical features, advanced cognitive abilities, and their highly social nature. It\'s not just simple mimicry; it\'s a complex behavior driven by several factors:\n\n1.  **Unique Vocal Anatomy:**\n    *   **Syrinx:** Unlike humans who use a larynx, birds have a syrinx, located at the base of the trachea. Parrots have an exceptionally flexible and muscular syrinx, allowing them to produce a wide range of sounds, including those that mimic human speech.\n    *   **Tongue:** Parrots also have a thick, muscular tongue that they can manipulate with surprising dexterity, similar to how humans use their tongue for articulation.\n\n2.  **Advanced Vocal Learning Brain:**\n    *   **Specialized Brain Regions:** Parrots possess unique brain structures dedicated to vocal learning. They have "vocal learning centers" (analogous to song nuclei in songbirds) with distinctive "shells" – outer regions that are particularly well-developed in parrots compared to other vocal-learning birds. These areas allow them to learn and produce novel sounds, not just rely on innate calls.\n    *   **Auditory Memory:** They have excellent auditory memory, enabling them to remember sounds and phrases they hear.\n    *   **Association:** While they don\'t "understand" speech in the human sense, they are incredibly adept at associating sounds and phrases with specific contexts, objects, people, or actions. For example, a parrot might learn to say "hello" when someone enters the room or "bye-bye" when someone leaves.\n\n3.  **Highly Social Nature:**\n    *   **Flock Communication:** Parrots are highly social animals in the wild, living in large flocks. Communication is crucial for maintaining flock cohesion, identifying individuals, warning of predators, and sharing information. Their ability to learn and mimic calls from other birds and environmental sounds helps them integrate and communicate within their group.\n    *   **Integration and Bonding:** In a human household, a parrot often views its human caregivers as its "flock." Mimicking human speech and sounds is a way for them to try and communicate, bond, seek attention, and integrate themselves into the human social environment. If mimicking a sound or phrase gets a positive reaction (attention, treat, praise), the parrot is more likely to repeat it.\n    *   **Environmental Mimicry:** Beyond human speech, parrots often mimic other sounds in their environment, like doorbells, phone rings, alarm clocks, or even the meow of a cat, demonstrating their general ability to pick up and reproduce sounds they hear frequently.\n\nIn essence, parrots "talk" because they have the physical tools, the brainpower to learn and remember sounds, and a strong social drive to communicate and bond with their flock, whether that flock consists of other parrots or humans.'

# %%
### ChatOpenAI
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-5.1")
response=model.invoke("Hi, How are you buddy?")
response
# Out:
# AIMessage(content='Doing well, thanks for asking. How are you doing today, and what can I help you with?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 13, 'total_tokens': 43, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.1-2025-11-13', 'system_fingerprint': None, 'id': 'chatcmpl-EP6RTjeAq7ZsiFaL8YIFqxmtTpocD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0af8d-414e-7221-ac75-0f821b507972-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 30, 'total_tokens': 43, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)
response=model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots talk primarily because they possess a unique combination of **biological, social, and cognitive traits** that allow them to mimic a wide range of sounds, including human speech. It\'s not just a random trick; it serves several important purposes for them.\n\nHere\'s a breakdown of the key reasons:\n\n1.  **Exceptional Vocal Learning Ability:**\n    *   **Specialized Brain Structures:** Parrots have highly developed vocal learning centers in their brains that are more complex than those found in most other birds. These "song nuclei" allow them to learn and produce new sounds throughout their lives, unlike many animals that are born with a fixed set of vocalizations.\n    *   **Vocal Anatomy:** They have a flexible tongue and a unique voice box called a **syrinx** that allows for precise control over sound production, enabling them to articulate sounds similar to human vowels and consonants.\n\n2.  **Highly Social Nature:**\n    *   **Flock Animals:** Parrots are incredibly social creatures that live in large flocks in the wild. Vocal communication is crucial for maintaining flock cohesion, identifying individuals, warning of predators, and finding food.\n    *   **Contact Calls:** They use specific "contact calls" to stay in touch with their flock members, especially when out of sight. Mimicking the sounds of their "flock" (whether other parrots or human companions) helps them feel integrated and secure.\n    *   **Bonding:** In a human household, a parrot often views its human caregivers as its flock. Mimicking human speech is a powerful way for them to bond, gain attention, and feel like a part of the family unit.\n\n3.  **Attention and Integration:**\n    *   **Reinforcement:** When a parrot talks, humans often react with excitement, attention, food, or praise. This positive reinforcement encourages the parrot to talk more. They quickly learn that vocalizing human words gets them what they want or need.\n    *   **Survival Strategy:** In a captive environment, being able to communicate with their human caregivers (even if it\'s just mimicry) can be a survival advantage, allowing them to express needs, desires, or discomfort.\n\n4.  **Intelligence and Cognitive Abilities:**\n    *   Parrots are highly intelligent birds capable of problem-solving and forming associations. While not all talking parrots understand the meaning of the words they say, some (like the famous Alex the African Grey) have demonstrated an astonishing ability to use words in context and even formulate simple phrases to express concepts. This suggests a cognitive capacity beyond simple mimicry for some individuals.\n    *   **Curiosity:** Their intelligence likely drives a curiosity about sounds in their environment, leading them to experiment with and replicate them.\n\nIn essence, parrots talk because they have the **biological hardware** (brain and syrinx), the **social drive** (to bond and belong), and the **cognitive capacity** (intelligence and learning ability) to do so. It\'s a fascinating display of their adaptability and social intelligence.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0af8f-beed-7013-8fee-437e5542f4c3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 1737, 'total_tokens': 1743, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1110}})

# %%
### Groq Model Integration
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]= os.getenv("GROQ_API_KEY")

model = init_chat_model("openai/gpt-oss-120b", model_provider="groq")

### Groq Model Integration

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model(
    "openai/gpt-oss-120b",
    model_provider="groq",
)

response = model.invoke("What is the weather in India?")
response.content
response.content
